# %% [markdown]
# # Notebook 1: Ingest MedRAG from local JSON
#
# Downloads **textbooks (700)**, **pubmed (1000)**, and **wikipedia (300, medical-filtered)** rows, merges to `records.json`, chunks to `data/processed/chunks/chunks.jsonl`, then indexes **Elasticsearch** and **Qdrant** with OpenAI `text-embedding-3-small`.

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# /Users/aditya.gurung/Downloads/Medjuras.AI-Assistant-RAG-for-healthcare-research-compliance/.venv/bin/python
# 3.9.6 (default, Apr 17 2026, 18:15:52)
# [Clang 21.0.0 (clang-2100.1.1.101)]

# %%
import _bootstrap  # noqa: F401
from ingestion.pipeline import run_ingest_pipeline
from evaluation.results_utils import copy_to_results

path = run_ingest_pipeline()
print('Chunks:', path)
copy_to_results(path, 'chunks.jsonl')

# %% [markdown]
# If running pipeline manually need to start docker compose

# %%
import _bootstrap  # noqa: F401
from ingestion.es_ingest import ingest_chunks as es_ingest
from ingestion.qdrant_ingest import ingest_chunks as qdrant_ingest

n_es = es_ingest(wipe=True)
n_qd = qdrant_ingest(wipe=True)
print(f'ES={n_es}, Qdrant={n_qd}')
# Out:
# /Users/aditya.gurung/Downloads/Medjuras.AI-Assistant-RAG-for-healthcare-research-compliance/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ES URL: http://localhost:9200 | index: medical_docs
# Waiting for Elasticsearch...
# Elasticsearch is up.
# Waiting for index 'medical_docs'...
# Index 'medical_docs' status: green
# Loading chunks.jsonl: 0line [00:00, ?line/s]
# ES bulk ingest:   0%|          | 0/13 [00:00<?, ?it/s]
# Qdrant URL: http://localhost:6333 | collection: medjuris
# Loading chunks.jsonl: 0line [00:00, ?line/s]
# Qdrant ingest batches:   0%|          | 0/38 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[2], line 6
#       3 from ingestion.qdrant_ingest import ingest_chunks as qdrant_ingest
#       5 n_es = es_ingest(wipe=True)
# ----> 6 n_qd = qdrant_ingest(wipe=True)
#       7 print(f'ES={n_es}, Qdrant={n_qd}')
#
# File ~/Downloads/Medjuras.AI-Assistant-RAG-for-healthcare-research-compliance/app/ingestion/qdrant_ingest.py:90, in ingest_chunks(chunks_path, qdrant_url, collection, wipe, batch_size)
#      88 batch = prepared[i : i + batch_size]
#      89 texts = [build_embed_text(p["title"], p["text"]) for _pid, p in batch]
# ---> 90 vectors = embed_texts(texts)
#      91 points = [
#      92     PointStruct(
#      93         id=str(uuid.uuid5(uuid.NAMESPACE_DNS, pid)),
#    (...)
#      97     for (pid, payload), vec in zip(batch, vectors)
#      98 ]
#      99 client.upsert(collection_name=collection, points=points)
#
# File ~/Downloads/Medjuras.AI-Assistant-RAG-for-healthcare-research-compliance/app/llm/embeddings.py:39, in embed_texts(texts, model)
#      37 client = get_embedding_client()
#      38 model = model or EMBEDDING_MODEL
# ---> 39 response = client.embeddings.create(model=model, input=list(texts))
#      40 return [item.embedding for item in response.data]
#
# File ~/Downloads/Medjuras.AI-Assistant-RAG-for-healthcare-research-compliance/.venv/lib/python3.9/site-packages/openai/resources/embeddings.py:136, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     130             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     131                 base64.b64decode(data), dtype="float32"
#     132             ).tolist()
#     134     return obj
# --> 136 return self._post(
#     137     "/embeddings",
#     138     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     139     options=make_request_options(
#     140         extra_headers=extra_headers,
#     141         extra_query=extra_query,
#     142         extra_body=extra_body,
#     143         timeout=timeout,
#     144         post_parser=parser,
#     145         security={"bearer_auth": True},
#     146     ),
#     147     cast_to=CreateEmbeddingResponse,
#     148 )
#
# File ~/Downloads/Medjuras.AI-Assistant-RAG-for-healthcare-research-compliance/.venv/lib/python3.9/site-packages/openai/_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Downloads/Medjuras.AI-Assistant-RAG-for-healthcare-research-compliance/.venv/lib/python3.9/site-packages/openai/_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# PermissionDeniedError: <html>
#
#  <head>
#        <meta content="text/html"  http-equiv="Content-Type">
#        <title>Skyhigh - Notification</title>
#
# 	<script type="text/javascript" src="/mwg-internal/de5fs23hu73ds/$SaPvfRzZZi2422FbTHgVt6ECq4fv_wuyMSNNE1L1Nxw,/files/javascript/sw.js" type="text/javascript" ></script>
#  	<script type="text/javascript" src="/mwg-internal/de5fs23hu73ds/$SaPvfRzZZi2422FbTHgVt6ECq4fv_wuyMSNNE1L1Nxw,/files/BAYERCOORPORATEDesign20262013/assets/jquery.min.js"></script>
#  	<script type="text/javascript" src="/mwg-internal/de5fs23hu73ds/$SaPvfRzZZi2422FbTHgVt6ECq4fv_wuyMSNNE1L1Nxw,/files/BAYERCOORPORATEDesign20262013/assets/bootstrap.min.js"></script>
#
#     <style>
#         @font-face {
#             font-family: 'BayerSans';
#             src: url('/mwg-internal/de5fs23hu73ds/$SaPvfRzZZi2422FbTHgVt6ECq4fv_wuyMSNNE1L1Nxw,/files/BAYERCOORPORATEDesign20262013/fonts/typeface_bayer_sans/Bayer Sans/Bayer Sans/Web Typeface/Normal/BayerSansWeb-Regular.woff2') format('woff2');
#             font-weight: normal;
#             font-style: normal;
#         }
#
#         @font-face {
#             font-family: 'BayerSans';
#             src: url('/mwg-internal/de5fs23hu73ds/$SaPvfRzZZi2422FbTHgVt6ECq4fv_wuyMSNNE1L1Nxw,/files/BAYERCOORPORATEDesign20262013/fonts/typeface_bayer_sans/Bayer Sans/Bayer Sans/Web Typeface/Normal/BayerSansWeb-Bold.woff2') format('woff2');
#             font-weight: bold;
#             font-style: normal;
#         }
#
#         body, * {            font-family: 'BayerSans', Arial, sans-serif !important;        }
#     </style>
#    <link href="/mwg-internal/de5fs23hu73ds/$SaPvfRzZZi2422FbTHgVt6ECq4fv_wuyMSNNE1L1Nxw,/files/BAYERCOORPORATEDesign20262013/bayer.css" rel="stylesheet">
#    <script language="JavaScript">
#            function decodeEntities(s){    var str, temp= document.createElement('p');    temp.innerHTML= s;    str= temp.textContent || temp.innerText;    temp=null;    return str; }
#    </script>
# </head>
#
#  <!--Body-->
# <body class="bodybg"  onload="swOnLoad();">
# <div class="container content">
#    <div class=""><div class="logo_container">
#       <div class="row">
#           <div class="col-md-12 text-right">
# 	<img src="/mwg-internal/de5fs23hu73ds/$SaPvfRzZZi2422FbTHgVt6ECq4fv_wuyMSNNE1L1Nxw,/files/BAYERCOORPORATEDesign20262013/images/Bayer.png" class="img-responsive logo" style="float: left; max-width: 100%; height: auto; margin: 0;">
#          </div>
#       </div>
#    </div>
# </div>
# <div class="section innercontent">
#     <div class="container">
#        <div class="row">
#           <div class="col-md-12">
#              <div class="section">
#                <div class="container">
#                  <div class="row">
#  	 <p><h2 class="headline notopspace"><font color="#CC0000">PROTECT DATA LIKE IT'S YOURS</font></h2></p>
# <br>
# Accelerating enterprise-wide AI transformation is one of Bayer’s five key priorities. Coupled with our DSO operating model, this is an opportunity we intend to leverage with your support. In doing so, we must act responsibly and choose tools that minimize risk for our company and those we serve.
# <br>
# <br>
# <b>As such, tools such as ChatGPT, Claude, DeepSeek, Grok, Meta and OpenAI must be accessed through <a href=https://chat.int.bayer.com/>myGenAssist</a>  (mGA) - our approved, secure AI platform.</b>
# <br>
# <b>Use myGenAssist (mGA) for approved, secure AI</b>
# <ul>
# <li>	mGA gives you vetted generative AI tools inside a secure, compliant environment so you can innovate faster while protecting Bayer data and IP.
# <li>	Work faster and innovate confidently while keeping Bayer data and IP protected.
# </ul>
# <br>
# <b><a href=https://chat.int.bayer.com >Go to myGenAssist</a></b><br>
# <br>
# <b>why this matters to our customers - and to Bayer</b>
# <ul>
# <li>	Protecting customer and patient data preserves trust, privacy and regulatory compliance.
# <li>	Protecting Baye's intellectual property preserves our competitive advantage, the integrity of future products and solutions, and the investments that power
# innovation.
# </ul>
# <br>
# <b>Need access to the blocked site for a valid business reason?</b>
# <ul>
# <li>	Contact you <a href=https://bayersi.service-now.com/efservices?id=kb_article&sysparm_article=KB0220767>local IT Service Desk</a> for assistance.
# </ul>
# <br>
# <b>Getting started with myGenAssist and other approved generative AI tools</b>
# <ul>
# <li>	Explore <a href=https://bayernet.int.bayer.com/de-de/bayer/digital/ai-at-bayer/ai-tools-at-bayer>AI Tools at Bayer</a> for quick tips, security guidance and best practices.
# </ul>
# <br>
# Thank you for helping keep customers, colleagues and Bayer’s innovations safe while we leverage AI responsibly.
#
# 	<br>
#
# <img style ="float:right;" src='/mwg-internal/de5fs23hu73ds/$SaPvfRzZZi2422FbTHgVt6ECq4fv_wuyMSNNE1L1Nxw,/files/BAYERCOORPORATEDesign20262013/images/security_starts_with_you.jpg' alt="Security starts with you">
#                   </div>
#                </div>
#             </div>
#         </div>
#      </div>
#   </div>
# </div>
#
# <div class="sitefooter">
#      <div class="col-sm-9">
#             <p><a href="#" data-toggle="modal" data-target="#debug_modal">Debug Information</a></p>
#       </div>
#       <div class="col-sm-3 footer-infos">
#            <p> https://api.openai.com/v1/embeddings | aditya.gurung | 192.168.1.14 | 0.0.0.0 |  2026-06-08T14:33:34.369Z</p>
#      </div>
#  </div>
#
#  	</div> <!--wrapper-->
#
#
#  <!--/Body-->
#  <!--Modal-->
# <div class="modal fade" id="debug_modal">
#   <div class="modal-dialog">
#      <div class="modal-content">
#        <div class="modal-header">
#             <button type="button" class="close" data-dismiss="modal" aria-hidden="true">x</button>
#            < h4 class="modal-title">Debug Information</h4>
#        </div>
#        <div class="modal-body">
#          <div class="panel-group" id="accordion">
#              <div class="panel panel-default">
#                 <div class="panel-heading">
#                   <h4 class="panel-title debug">
# 								  <a href="#collapseOne" data-toggle="collapse" data-parent="#accordion">
# 									General Information
# 								  </a>
# 								</h4>
#
# 						</div>
# 						<div class="panel-collapse collapse in" id="collapseOne">
# 							<div class="panel-body debug">
# 						<h5><b>Requested Url:</b></h5>
# 						<p> https://api.openai.com/v1/embeddings</p>
# 																			<h5><b>Proxy:</b></h5>
# 						<p>0.0.0.0 (8080)  284-prod-mwg-8  / false</p>
# 						<h5><b>VIP:</b></h5>
# 						<p>0.0.0.0  </p>
# 						<h5><b>Last Rule:</b></h5>
# 						<p>DENY access to GLB-CIO-AI</p>
# 						<h5><b>User:</b></h5>
# 						<p>aditya.gurung  (192.168.1.14) / (Mac-KH36F379FN)</p>
# 						<h5><b>Header:</b></h5>
# 						<p>OpenAI/Python 2.41.0</p>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="panel panel-default">
# 						<div class="panel-heading ">
# 							 <h4 class="panel-title debug">
# 								  <a href="#collapseTwo" data-toggle="collapse" data-parent="#accordion">
# 									Group
# 								  </a>
# 								</h4>
# 						</div>
# 						<div class="panel-collapse collapse" id="collapseTwo">
# 							<div class="panel-body debug">
# 							cs.u.AllAccess-Employees;ef.a.APAC_All_Employees;ef.a.DP-users-global;ef.u.India_EnablingFuction_Employees;cpl.u.Bayer_MFAR_FTE;ef.u.DHub_India_CH;ef.u.IT-TE-CHDA-E;ef.a.isc_default_access;ef.u.it-dtch-global;ef.u.cyber_security_developer_newsletter;ef.u.dhub_india;ef.u.it-global;ef.u.it-te-chda;ef.u.it-te-global;ef.u.efds-dldb-p-ar-insightsnow_fact;ef.u.ch.daa.all.businessanalyst;ef.u.com-all-ef-employee;ef.u.dt-itch-pp-sw-engineers;ef.a.bayer_all_employees_noembargo;BR_AD_MBX_AllActiveUsers;ef.u.ch.daa.rda.repo.maintain;ef.u.ch.daa.cda.prdct.repo.maintain;ef.u.ch.daa.cda.prdct.datalakereader;ef.u.ch.daa.gma.businessanalyst;ef.u.ch.daa.rda.dataengineer.dev;ef.a.ch.daa.all.mfa;EF.U.ELSA-DLDB-D-AR-ASSETANALYST;EF.U.ELSA-DLDB-P-AR-ASSETANALYST;EF.U.ELSA-DLDB-Q-AR-ASSETANALYST;ef.a.elsa-sf-p-bu-assetanalyst;ef.a.elsa-sf-q-bu-assetanalyst;ef.a.elsa-sf-d-bu-assetanalyst;ef.u.ch.daa.cda.prdct.dataengineer.dev;ef.u.ch.daa.cda.prdct.cicdadmin;ef.u.chac-dldb-q-ar-analyst;ef.u.chac-dldb-p-ar-analyst;ef.u.chac-dldb-d-ar-developer;ef.u.ch.daa.all.developers;ef.a.bayer_it_employees;EF.U.ch.daa.platform.dms.user;ef.u.ch.daa.cda.fico.businessanalyst;ef.u.chac-dldb-d-ar-analyst;ef.u.chac-dldb-p-ar-developer;ef.u.chac-dldb-q-ar-developer;ef.u.lefim_reporting;ef.a.ch.analytics.m360.anyuser;ef.u.ch.analytics.m360.global;ef.u.ch.analytics.nrm.enduser;ef.u.ch.analytics.nrm.au.enduser;ef.u.ch.analytics.nrm.es.enduser;ef.u.ch.analytics.nrm.pt.enduser;ef.u.ch.analytics.nrm.de.enduser;ef.u.ch.analytics.nrm.cn.enduser;ef.u.ch.analytics.nrm.ru.enduser;ef.u.ch.analytics.nrm.br.enduser;ef.u.ch.analytics.nrm.us.enduser;ef.u.ch.analytics.nrm.at.enduser;ef.u.ch.analytics.nrm.ch.enduser;ef.u.ch.analytics.nrm.mx.enduser;ef.u.ch.analytics.nrm.uk.enduser;ef.u.ch.analytics.nrm.tr.enduser;EF.U.ch.analytics.nrm.it.enduser;ef.a.data.one.hana_workloadclass_l;bs.u.d1.comm.rep.managementreporting_a-g;bs.u.d1.comm.rep.functionalpackage_a-k;BBS.A.Bayer_All_Employees;fi.a.bag-acc-bka_h2r;bs.u.2641.SSCDN.Bangalore.ALL_EMPLOYEES
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# </div>
# </html>
