# %% [markdown]
# # Notebook 1: Ingest MedRAG from Hugging Face
#
# Downloads **textbooks (700)**, **pubmed (1000)**, and **wikipedia (300, medical-filtered)** rows, merges to `records.json`, chunks to `data/processed/chunks/chunks.jsonl`, then indexes **Elasticsearch** and **Qdrant** with OpenAI `text-embedding-3-small`.

# %%
import _bootstrap  # noqa: F401
from ingestion.pipeline import run_ingest_pipeline
from evaluation.results_utils import copy_to_results

path = run_ingest_pipeline()
print('Chunks:', path)
copy_to_results(path, 'chunks.jsonl')
# Out:
# Downloading MedRAG sources:   0%|          | 0/3 [00:00<?, ?file/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/2.62k [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/18 [00:00<?, ?it/s]
# Streaming MedRAG/textbooks: 0row [00:00, ?row/s]
# README.md:   0%|          | 0.00/2.56k [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/1166 [00:00<?, ?it/s]
# Streaming MedRAG/pubmed: 0row [00:00, ?row/s]
# README.md:   0%|          | 0.00/2.79k [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/646 [00:00<?, ?it/s]
# Streaming MedRAG/wikipedia: 0row [00:00, ?row/s]
# Loading MedRAG raw files:   0%|          | 0/3 [00:00<?, ?file/s]
# Loading textbooks.json:   0%|          | 0.00/716k [00:00<?, ?B/s]
# Loading pubmed.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Loading wikipedia.json:   0%|          | 0.00/281k [00:00<?, ?B/s]
# Loading merged records:   0%|          | 0.00/2.39M [00:00<?, ?B/s]
# Chunking records:   0%|          | 0/2000 [00:00<?, ?doc/s]
# Writing chunks JSONL:   0%|          | 0/2420 [00:00<?, ?chunk/s]
# Chunks: /workspaces/Medjuras.AI-Assistant-RAG-for-healthcare-research-compliance/data/processed/chunks/chunks.jsonl
# PosixPath('/workspaces/Medjuras.AI-Assistant-RAG-for-healthcare-research-compliance/results/chunks.jsonl')

# %%
import _bootstrap  # noqa: F401
from ingestion.es_ingest import ingest_chunks as es_ingest
from ingestion.qdrant_ingest import ingest_chunks as qdrant_ingest

n_es = es_ingest(wipe=True)
n_qd = qdrant_ingest(wipe=True)
print(f'ES={n_es}, Qdrant={n_qd}')
# Out:
# 2026-06-02 09:44:35.835349506 [W:onnxruntime:Default, device_discovery.cc:133 GetPciBusId] Skipping pci_bus_id for PCI path at "/sys/devices/LNXSYSTM:00/LNXSYBUS:00/PNP0A03:00/device:07/VMBUS:01/5620e0c7-8062-4dce-aeb7-520c7ef76171" because filename "5620e0c7-8062-4dce-aeb7-520c7ef76171" did not match expected pattern of [0-9a-f]+:[0-9a-f]+:[0-9a-f]+[.][0-9a-f]+
# ES URL: http://localhost:9200 | index: medical_docs
# Waiting for Elasticsearch...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 5
#       1 import _bootstrap  # noqa: F401
#       2 from ingestion.es_ingest import ingest_chunks as es_ingest
#       3 from ingestion.qdrant_ingest import ingest_chunks as qdrant_ingest
#       4
# ----> 5 n_es = es_ingest(wipe=True)
#       6 n_qd = qdrant_ingest(wipe=True)
#       7 print(f'ES={n_es}, Qdrant={n_qd}')
#
# File /workspaces/Medjuras.AI-Assistant-RAG-for-healthcare-research-compliance/app/ingestion/es_ingest.py:135, in ingest_chunks(chunks_path, es_url, index, wipe)
#     133 print(f"ES URL: {es_url} | index: {index}", flush=True)
#     134 es = Elasticsearch(es_url, request_timeout=120, retry_on_timeout=True, max_retries=5)
# --> 135 wait_for_es(es)
#     136 ensure_index(es, index, wipe=wipe)
#     137 wait_for_index(es, index)
#
# File /workspaces/Medjuras.AI-Assistant-RAG-for-healthcare-research-compliance/app/ingestion/es_ingest.py:53, in wait_for_es(es, timeout)
#      51         pass
#      52     time.sleep(2)
# ---> 53 raise RuntimeError(
#      54     "Elasticsearch did not become ready. Start it with: docker compose up -d elasticsearch"
#      55 )
#
# RuntimeError: Elasticsearch did not become ready. Start it with: docker compose up -d elasticsearch
