# %% [markdown]
# # Notebook 2: Ground truth (200 Q&A)
#
# Generates **200** exam-style questions answerable **only** from ingested chunks using **gpt-oss-120b**. Writes `data/evaluation/ground_truth.json` and copies to `results/`.

# %%
import _bootstrap  
from ingestion.paths import CHUNKS_JSONL, GROUND_TRUTH_JSON
from evaluation.ground_truth import generate_ground_truth
from evaluation.results_utils import copy_to_results

p = generate_ground_truth(CHUNKS_JSONL, sample_size=200, out_path=GROUND_TRUTH_JSON)
copy_to_results(p, 'ground_truth.json')
print(p)
# Out:
# Loading chunks: 0line [00:00, ?line/s]
# Generating ground truth (openai):   0%|          | 0/200 [00:00<?, ?chunk/s]
# /Users/aditya.gurung/Downloads/Medjuras.AI-Assistant-RAG-for-healthcare-research-compliance/data/evaluation/ground_truth.json
