# %% [markdown]
# # Notebook 4: Semantic evaluation (Qdrant)
#
# Evaluates dense retrieval with OpenAI embeddings.

# %%
import _bootstrap  # noqa: F401
import json
from evaluation.config_paths import load_ground_truth
from evaluation.eval_utils import evaluate
from evaluation.results_utils import results_path, results_images_dir
from evaluation.retrieval_results_charts import save_single_method_plot
from search.qdrant_search import search_qdrant

TOP_K = 10
gt = load_ground_truth()
gt_rows = [{'query': r['question'], 'doc_id': r['doc_id']} for r in gt]
metrics = evaluate(gt_rows, lambda q, **kw: search_qdrant(q, top_k=TOP_K, local=True), top_k=TOP_K)
out = results_path('qdrant_dense_metrics.json')
out.write_text(json.dumps(metrics, indent=2), encoding='utf-8')
png = save_single_method_plot('Qdrant', metrics, TOP_K, results_images_dir() / 'qdrant_dense_metrics.png')
print(metrics)
print('Saved chart:', png)
# Out:
# /Users/aditya.gurung/Downloads/Medjuras.AI-Assistant-RAG-for-healthcare-research-compliance/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Loading ground truth:   0%|          | 0.00/38.0k [00:00<?, ?B/s]
# Evaluating retrieval:   0%|          | 0/200 [00:00<?, ?query/s]
# {'Hit@10': 0.985, 'MRR@10': 0.8418869047619044, 'MAP@10': 0.8418869047619044, 'nDCG@10': 0.877405968200412}
# Saved chart: /Users/aditya.gurung/Downloads/Medjuras.AI-Assistant-RAG-for-healthcare-research-compliance/results/images/qdrant_dense_metrics.png
